# %%
# !pip install mediapipe emoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import cv2
import mediapipe as mp
import random
import emoji
import gradio as gr

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

# Function to detect hand gesture
def detect_hand_gesture(frame):
    # Convert BGR image to RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame and detect hands
    results = hands.process(rgb_frame)

    # Get hand landmarks
    if results.multi_hand_landmarks:
        # Implement logic to detect rock, paper, or scissors gesture
        # You'll need to define the detection logic here
        pass  # Placeholder for gesture detection

    return "✊"  # Default choice for now

# Function for computer's random choice (rock, paper, or scissors)
def computer_choice():
    return random.choice(["✊", "✋", "✌"])

# Function to determine the game result
def determine_winner(player_choice, computer_choice):
    # Implement game rules (rock beats scissors, scissors beats paper, etc.)
    # You'll need to define the rules and check who wins
    return "Player"  # Placeholder for game result

# Function to run the game
def play_game(player_choice):
    computer_choice = computer_choice()
    winner = determine_winner(player_choice, computer_choice)
    result = f"Your choice: {player_choice}\nComputer's choice: {computer_choice}\n"

    if winner == "Player":
        result += "You win!"
    elif winner == "Computer":
        result += "Computer wins!"
    else:
        result += "It's a tie!"

    return result

# Define Gradio interface
iface = gr.Interface(
    fn=play_game,
    inputs=gr.inputs.Textbox(placeholder="✊"),
    outputs="text",
    live=True,
    capture_session=True,
)

# Launch Gradio interface
iface.launch()
# Out:
# <ipython-input-8-9747e0f4fdb2>:55: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   inputs=gr.inputs.Textbox(placeholder="✊"),
# <ipython-input-8-9747e0f4fdb2>:55: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   inputs=gr.inputs.Textbox(placeholder="✊"),
# <ipython-input-8-9747e0f4fdb2>:55: GradioDeprecationWarning: `numeric` parameter is deprecated, and it has no effect
#   inputs=gr.inputs.Textbox(placeholder="✊"),
# <ipython-input-8-9747e0f4fdb2>:53: GradioDeprecationWarning: `capture_session` parameter is deprecated, and it has no effect
#   iface = gr.Interface(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.

# %%
import cv2
import mediapipe as mp
import random
import emoji
import gradio as gr

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

# Function to detect hand gesture
def detect_hand_gesture(frame):
    # Convert BGR image to RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame and detect hands
    results = hands.process(rgb_frame)

    # Get hand landmarks
    if results.multi_hand_landmarks:
        # Implement logic to detect rock, paper, or scissors gesture
        # You'll need to define the detection logic here
        pass  # Placeholder for gesture detection

    return "✊"  # Default choice for now

# Function for computer's random choice (rock, paper, or scissors)
def computer_choice():
    return random.choice(["✊", "✋", "✌"])

# Function to determine the game result
def determine_winner(player_choice, computer_choice):
    # Implement game rules (rock beats scissors, scissors beats paper, etc.)
    # You'll need to define the rules and check who wins
    return "Player"  # Placeholder for game result

# Function to run the game
def play_game(webcam_frame):
    player_choice = detect_hand_gesture(webcam_frame)
    computer_choice_emoji = computer_choice()
    winner = determine_winner(player_choice, computer_choice_emoji)

    result = f"Your choice: {player_choice}\nComputer's choice: {computer_choice_emoji}\n"

    if winner == "Player":
        result += "You win!"
    elif winner == "Computer":
        result += "Computer wins!"
    else:
        result += "It's a tie!"

    return result

# Define Gradio interface
iface = gr.Interface(
    fn=play_game,
    inputs=gr.inputs.Webcam(),  # Use Webcam input to capture gestures
    outputs="text",
    live=True,
)

# Launch Gradio interface
iface.launch()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-47de52a33a4a> in <cell line: 55>()
#      55 iface = gr.Interface(
#      56     fn=play_game,
# ---> 57     inputs=gr.inputs.Webcam(),  # Use Webcam input to capture gestures
#      58     outputs="text",
#      59     live=True,
#
# AttributeError: module 'gradio.inputs' has no attribute 'Webcam'

# %%
import cv2
import mediapipe as mp
import random
import emoji
import gradio as gr

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()

# Function to detect hand gesture
def detect_hand_gesture(frame):
    # Convert BGR image to RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Process the frame and detect hands
    results = hands.process(rgb_frame)

    # Get hand landmarks
    if results.multi_hand_landmarks:
        # Implement logic to detect rock, paper, or scissors gesture
        # You'll need to define the detection logic here
        pass  # Placeholder for gesture detection

    return "✊"  # Default choice for now

# Function for computer's random choice (rock, paper, or scissors)
def computer_choice():
    return random.choice(["✊", "✋", "✌"])

# Function to determine the game result
def determine_winner(player_choice, computer_choice):
    # Implement game rules (rock beats scissors, scissors beats paper, etc.)
    # You'll need to define the rules and check who wins
    return "Player"  # Placeholder for game result

# Function to run the game
def play_game(video_frames):
    webcam_frame = video_frames[0]
    player_choice = detect_hand_gesture(webcam_frame)
    computer_choice_emoji = computer_choice()
    winner = determine_winner(player_choice, computer_choice_emoji)

    result = f"Your choice: {player_choice}\nComputer's choice: {computer_choice_emoji}\n"

    if winner == "Player":
        result += "You win!"
    elif winner == "Computer":
        result += "Computer wins!"
    else:
        result += "It's a tie!"

    return result

# Define Gradio interface
iface = gr.Interface(
    fn=play_game,
    inputs=gr.inputs.Video(type="opencv", label="Rock-Paper-Scissors Game"),  # Use Video input to capture gestures
    outputs="text",
    live=True,
)

# Launch Gradio interface
iface.launch()
# Out:
# <ipython-input-10-5674ae93d985>:58: GradioDeprecationWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   inputs=gr.inputs.Video(type="opencv", label="Rock-Paper-Scissors Game"),  # Use Video input to capture gestures
# <ipython-input-10-5674ae93d985>:58: GradioDeprecationWarning: `optional` parameter is deprecated, and it has no effect
#   inputs=gr.inputs.Video(type="opencv", label="Rock-Paper-Scissors Game"),  # Use Video input to capture gestures
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
